# %%
# !pip install stemgraphic
import stemgraphic
data = (0.2,3.7,0.6,0.1,3.1,8.9,1.5,8.0,0.1,4.4,2.4,0.1,1.2,13.7,8.9,1.9,8.0,12.7,4.6,0.7,3.2,11.0,2.8,4.9,1.5,0.2,5.5,0.5,4.1,0.3,0.7,6.6,4.9,7.9,0.0,1.3,3.5,6.1,0.1,1.7,3.1,2.6)
stemgraphic.stem_graphic(data, scale = 1, asc=False, aggregation=False)
# Out:
# ...
# (<Figure size 540x306 with 1 Axes>, <Axes:>)
